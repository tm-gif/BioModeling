# %% [markdown]
# Vectorized Deer

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib notebook

n_animals = 100 # # of animals
n_steps = 10000 #steps 
diffusion=0.05 #width of normal distribution

x = np.ones(n_animals)*0.5 #x array of ones that is the size of the amount of animals there are
y = np.ones(n_animals)*0.5 #y array of the same

#PLOTTING
fig = plt.figure(figsize = (5,5))
#plt.plot(x,y,'k.'); #plot
plt.xlim(0,1);
plt.ylim(0,1);
#plt.show()

for t in range(n_steps): #time in steps range
    x+=np.random.randn(n_animals)*diffusion #x adds a random number in the range on animals and multiplies it by speed
    y+=np.random.randn(n_animals)*diffusion
    #Looping through all the animals and checking four characteristics 
    
    
    #Not sure why these aren't working
    #np.where((x > 1), x, 1)
    #np.where((x < 0), x, 0) 
    #np.where((y < 0), y, 0)
    #np.where((y > 1), y, 1)

    x = np.maximum(x,1)  
    x = np.minimum(x,0)
    y = np.maximum(y,1)
    y = np.minimum(y,0)



    plt.cla()
    plt.plot(x,y,'k.', markersize = 5)
    plt.xlim(0,1);

    plt.ylim(0,1);
    fig.canvas.draw() #makes it move
    time.sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="500">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-de21f95cc101> in <module>
#      40     plt.ylim(0,1);
#      41     fig.canvas.draw() #makes it move
# ---> 42     time.sleep(0.01)
#      43
#
# KeyboardInterrupt:

# %% [markdown]
# Persistent Moose

# %% [markdown]
# To create a straight Effect, I am creating a speed vector and then reflecting it with negative speed. I don't knowif this implementation will work.

# %%
# %matplotlib notebook

n_animals = 100 # # of animals
n_steps = 10000 #steps 
diffusion=0.05 #width of normal distribution

x = np.ones(n_animals)*0.5 #x array of ones that is the size of the amount of animals there are
y = np.ones(n_animals)*0.5 #y array of the same

vx = np.random.randint(low=1, high=10, size=1)
vy = np.random.randint(low=1, high=10, size=1)


#PLOTTING
fig = plt.figure(figsize = (5,5))
#plt.plot(x,y,'k.'); #plot
#plt.xlim(0,1);
#plt.ylim(0,1);
#plt.show()

for t in range(n_steps): #time in steps range adding straight speed
    x = x + vx
    y = y + vy
    #Looping through all the animals and checking four characteristics with logical or

    if np.logical_or(x[t] < 0, x[t] > 1):
        vx = vx*(-1)
    if np.logical_or(y[t] < 0, y[t] > 1):
        vy = vy*(-1)


    #np.where((x > 1), x, 1)
    #np.where((x < 0), x, 0) 
    #np.where((y < 0), y, 0)
    #np.where((y > 1), y, 1)

    #x = np.maximum(x,1)  
    #x = np.minimum(x,0)
    #y = np.maximum(y,1)
    #y = np.minimum(y,0)



    plt.cla()
    plt.plot(x,y,'k.', markersize = 5)
    plt.xlim(0,1);

    plt.ylim(0,1);
    fig.canvas.draw() #makes it move
    time.sleep(0.01)

# %% [markdown]
# I think it makes more sense to use np.where for this part I just have not been able to implement it. The above code runs and then throughs an error, even through the animal does not move out of bounds

# %%
#A Test of the speed generating code

# %matplotlib notebook

n_animals = 100 # # of animals
n_steps = 10000 #steps 
#diffusion=0.05 #width of normal distribution
vmin = .01
vmax = .05

x = np.ones(n_animals)*0.5 #x array of ones that is the size of the amount of animals there are
y = np.ones(n_animals)*0.5 #y array of the same

vx = np.random.uniform(low = vmin, high = vmax, size = n_animals)*(2*np.random.randint(low = 0, high = 2, size = n_animals)-1)
vy = np.random.uniform(low = vmin, high = vmax, size = n_animals)*(2*np.random.randint(low = 0, high = 2, size = n_animals)-1)

# %%
# %matplotlib notebook

n_animals = 100 # # of animals
n_steps = 100 #steps 
#diffusion=0.05 #width of normal distribution
vmin = .01
vmax = .05

# x = np.ones(n_animals)*0.5 #x array of ones that is the size of the amount of animals there are
# y = np.ones(n_animals)*0.5 #y array of the same
x = np.random.uniform(size = n_animals)
y = np.random.uniform(size = n_animals)

vx = np.random.uniform(low = vmin, high = vmax, size = n_animals)*(2*np.random.randint(low = 0, high = 2, size = n_animals)-1)
vy = np.random.uniform(low = vmin, high = vmax, size = n_animals)*(2*np.random.randint(low = 0, high = 2, size = n_animals)-1)


#PLOTTING
fig = plt.figure(figsize = (5,5))
#plt.plot(x,y,'k.'); #plot
plt.xlim(0,1);
plt.ylim(0,1);


#fig.canvas.draw() #makes it move
#time.sleep(0.01)

for t in range(n_steps): #time in steps range adding straight speed
    x += vx
    y += vy
    #Looping through all the animals and checking four characteristics with logical or

    vx = np.where(np.logical_or(x > 1, x < 0), -vx, vx)    
    vy = np.where(np.logical_or(y > 1, y < 0), -vy, vy)  
    


    
    plt.cla()
    plt.plot(x,y,'k.', markersize = 5)
    plt.xlim(0,1);
    plt.ylim(0,1);
    fig.canvas.draw() #makes it move
    time.sleep(0.001)
# Out:
# <img src="data:image/png;base64,..." width="500">
