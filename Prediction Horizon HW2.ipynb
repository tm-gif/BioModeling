# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### I hoped to show change in r by utilizing a for loop to loop through significant values of r

# %%
#Logistic Growth Model
nsteps = 100 #number of steps in our lil simulation
ntraces = 10
x = np.zeros(shape = (nsteps, ntraces)) #Number of animals at every step
wiggle = .0001
r = 3.9
for r in np.arange(2.0,4.0):
    for itrace in range(ntraces):
        x[0,itrace] = .6 + np.random.rand(1)*wiggle
        for istep in range(1,nsteps): #The original number of animals
                x[istep,itrace] = r*x[istep-1, itrace]*(1-x[istep-1, itrace])

fig = plt.figure(figsize=(10,5))
#plt.plot(np.std(x,axis=1))
plt.plot(np.std(x, axis =1))
plt.xlabel('Time');
plt.ylabel('Variability (sd) of trajectories');

# %% [markdown]
# ### Utilizing a different approach to examine more concrete values yields a similar curve

# %%
#Logistic Growth Model
nsteps = 100 #number of steps in our lil simulation
ntraces = 10
x = np.zeros(shape = (nsteps, ntraces)) #Number of animals at every step
wiggle = .0001
rvals = (2.0,2.2,2.4,2.6,2.8,3.0,3.2,3.4,3.6,3.8,4.0)
for var in rvals:
    for itrace in range(ntraces):
        x[0,itrace] = .6 + np.random.rand(1)*wiggle
        for istep in range(1,nsteps): #The original number of animals
                x[istep,itrace] = r*x[istep-1, itrace]*(1-x[istep-1, itrace])

fig = plt.figure(figsize=(10,5))
#plt.plot(np.std(x,axis=1.5))
plt.plot(np.std(x, axis =1))
plt.xlabel('Time');
plt.ylabel('Variability (sd) of trajectories');

# %%
#a graph of the inability to predict the variability of the trajectories
#Measure of inability to predict as a measure of time
#Calculate the std of each point at each step

# %% [markdown]
# ## Something Different

# %%
#abs(X[i] - x[i-1])
#Logistic Growth Model
nsteps = 100 #number of steps in our lil simulation
ntraces = 10
x = np.zeros(shape = (nsteps, ntraces)) #Number of animals at every step
wiggle = .0001
rvals = (2.0,2.2,2.4,2.6,2.8,3.0,3.2,3.4,3.6,3.8,4.0)
for var in rvals:
    for itrace in range(ntraces):
        x[0,itrace] = .6 + np.random.rand(1)*wiggle
        for istep in range(1,nsteps): #The original number of animals
                x[istep,itrace] = r*x[istep-1, itrace]*(1-x[istep-1, itrace])

fig = plt.figure(figsize=(10,5))
#plt.plot(np.std(x,axis=1.5))
plt.plot(np.std(x, axis =1))
plt.xlabel('Time');
plt.ylabel('Variability (sd) of trajectories');

# %%
nsteps = 100 #number of steps in our lil simulation
ntrials = 1000 #the number of trials used to calculate and strengthen the confidence of each point and the curve shape

wiggle = .001 #shake factor
x = np.zeros(shape = (nsteps, 2)) #an array that is 100 by 2 (matrix)
diff = np.zeros(shape = (nsteps, ntrials)) #difference in the two trajectories
fig = plt.figure(figsize=(9,9)); #Changes size of plot

for r in np.arange(3.6,4.0,0.1):
    for itrial in range(ntrials):
        starting_point = np.random.uniform(low=0,high=1-wiggle) + np.array([0,wiggle])#defines the starting point of the two graphs
        for ipair in range(2): #the pairs?
                x[0,ipair] = starting_point[ipair] #for the ipairth row, the value is the random point
                for istep in range(1,nsteps): #the steps in time
                        x[istep,ipair] = r*x[istep-1, ipair]*(1-x[istep-1, ipair]) #
        diff[:,itrial]  = np.abs(x[:,1]-x[:,0]) #diff as the absolute value of the two curves x and x~     
    plt.plot(np.mean(diff, axis = 1), label = np.round(r,decimals=2)); #mean of the absolute values
